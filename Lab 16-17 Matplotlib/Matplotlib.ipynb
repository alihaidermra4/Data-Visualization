# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Line Plot

# %%
data = {
    "Year": [2015, 2016, 2017, 2018, 2019, 2020, 2021],
    "Sales": [20000, 25000, 30000, 28000, 32000, 31000, 35000]
}
df = pd.DataFrame(data)

# %%
plt.plot(df["Year"], df["Sales"])

# %%
plt.figure(figsize=(10, 6))
plt.plot(df["Year"], df["Sales"], marker='o', linestyle='-', color='r', label='Sales')
plt.title("Yearly Automobile Sales", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Sales", fontsize=12)
plt.xticks(df["Year"], rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
#plt.savefig("line_plot_1.png")
plt.show()

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Our First Graph!', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
#plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
data = {
    "Year": [2015, 2016, 2017, 2018, 2019, 2020, 2021],
    "Sedan": [15000, 16000, 14000, 13500, 12500, 11000, 12000],
    "SUV": [10000, 12000, 15000, 16000, 17000, 18000, 20000],
    "Truck": [8000, 9000, 8500, 8200, 8000, 7800, 7900],
}
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(12, 7))

# Plot each vehicle type
plt.plot(df["Year"], df["Sedan"], marker='o', linestyle='-', label='Sedan')
plt.plot(df["Year"], df["SUV"], marker='o', linestyle='-', label='SUV')
plt.plot(df["Year"], df["Truck"], marker='o', linestyle='-', label='Truck')


plt.title("Yearly Vehicle Sales Trends by Type", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Sales", fontsize=12)
plt.xticks(df["Year"], rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.savefig("line_plot_2.png")
plt.show()

# %%
# Sample dataset for GDP variations (replace with actual data if available)
data = {
    "Year": [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
    "GDP (Recession)": [2.0, 1.8, 1.5, 1.2, 1.0, 0.8, 0.5, 0.6, 0.7, 0.9],
    "GDP (Non-Recession)": [3.0, 3.2, 3.5, 3.8, 4.0, 3.8, 4.2, 4.5, 4.8, 5.0]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Create subplots
plt.figure(figsize=(14, 6))

# Subplot 1: GDP during Recession
plt.subplot(1, 2, 1)
plt.plot(df["Year"], df["GDP (Recession)"], marker='o', linestyle='-', color='r')
plt.title("GDP Variation During Recession")
plt.xlabel("Year")
plt.ylabel("GDP (%)")
plt.grid(True)

# Subplot 2: GDP during Non-Recession
plt.subplot(1, 2, 2)
plt.plot(df["Year"], df["GDP (Non-Recession)"], marker='o', linestyle='-', color='g')
plt.title("GDP Variation During Non-Recession")
plt.xlabel("Year")
plt.ylabel("GDP (%)")
plt.grid(True)

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig('Subplot.png')  # Saves the chart as Subplot.png in the current directory
plt.show()

# %%
"""Customized Line Plot"""

# Data for the plot
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
y2 = [8, 15, 30, 25]

# Create the plot
fig=plt.figure(figsize=(8, 3))
fig.add_subplot(1, 2, 1)
plt.plot(x, y, marker='+', linestyle='--', color='y', label='Stock A')
fig.add_subplot(1, 2, 2)
plt.plot(x, y2, marker='x', linestyle='-', color='r', label='Stock B')

# Add title and labels
plt.title('Stock Prices Over Time', fontsize=8)
plt.xlabel('Time (Days)', fontsize=8)
plt.ylabel('Stock Price (USD)', fontsize=8)

# Add a grid
plt.grid(True)

# Add a legend
plt.legend()

plt.show()

# %%
# Sample data for unemployment rate, vehicle type, and sales during recession (replace with actual data if available)
data = {
    "Year": [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Unemployment Rate (%)": [7.5, 7.8, 8.1, 800.3, 8.0, 10.5, 11.0, 10.8, 9.5],
    "SUV Sales": [1500, 1600, 1700, 1800, 1850, 1600, 1500, 1450, 1400],
    "Sedan Sales": [1200, 1250, 1300, 1350, 1400, 1200, 1100, 1050, 1000],
    "Truck Sales": [800, 850, 900, 950, 1000, 900, 850, 800, 750],
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Create the figure and axis for the line plot
plt.figure(figsize=(12, 8))

# Plot unemployment rate
plt.plot(df["Year"], df["Unemployment Rate (%)"], marker='o', linestyle='-', color='black', label="Unemployment Rate (%)")

# Plot sales for each vehicle type
plt.plot(df["Year"], df["SUV Sales"], marker='o', linestyle='-', color='r', label="SUV Sales")
plt.plot(df["Year"], df["Sedan Sales"], marker='o', linestyle='-', color='g', label="Sedan Sales")
plt.plot(df["Year"], df["Truck Sales"], marker='o', linestyle='-', color='b', label="Truck Sales")

# Add titles and labels
plt.title("Effect of Unemployment Rate on Vehicle Sales During Recession", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Sales / Unemployment Rate", fontsize=14)
plt.legend(title="Legend", fontsize=10)
plt.grid(True)

plt.show()

# %% [markdown]
# # Real World Examples
# Download data from my Github (gas_prices.csv & fifa_data.csv)

# %% [markdown]
# ### Line Graph

# %%
gas = pd.read_csv('gas_prices.csv')

plt.figure(figsize=(8,5))

plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(gas.Year, gas.USA, 'b.-', label='United States')
plt.plot(gas.Year, gas.Canada, 'r.-')
plt.plot(gas.Year, gas['South Korea'], 'g.-')
plt.plot(gas.Year, gas.Australia, 'y.-')

# Another Way to plot many values!
# countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']
# for country in gas:
#     if country in countries_to_look_at:
#         plt.plot(gas.Year, gas[country], marker='.')

plt.xticks(gas.Year[::3].tolist()+[2011])

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()

# %% [markdown]
# # Bar Plot

# %%
# Bar Plot
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 24, 36, 48, 50]
plt.figure(figsize=(8, 5))
plt.bar(categories, values, color='blue')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot')
plt.grid(True, alpha=0.5, linestyle ='--')
plt.show()

# %%
plt.bar(['Product A', 'Product B', 'Product C'], [10, 20, 15], color = ['blue','red','green'])
plt.title('Sales by Product')
plt.show()

# %%
# Create a sample dataset
np.random.seed(42)
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(10, 100, size=len(categories))

# Create a DataFrame
df = pd.DataFrame({'Category': categories, 'Value': values})

# Plot a bar chart
plt.figure(figsize=(8, 5))
plt.bar(df['Category'], df['Value'], color='skyblue', edgecolor='black')
plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Sample Bar Plot')
plt.show()

# %%
# Data for age groups
age_groups = ['18-24', '25-34', '35-44', '45-54', '55-64', '65+']
number_of_people = [50, 70, 60, 40, 30, 20]

plt.bar(age_groups, number_of_people, color='skyblue', edgecolor='black')

plt.title('Number of People in Each Age Group', fontsize=14)
plt.xlabel('Age Group')
plt.ylabel('Number of People')

plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

# %% [markdown]
# # Scatter Plot

# %%
# Sample data (replace with actual data if available)
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],
    "Sales": [1200, 1100, 1250, 1400, 1600, 1550, 1700, 1650, 1500, 1450, 1300, 1200],
    "Seasonality Impact": [10, 8, 9, 12, 15, 14, 16, 14, 13, 11, 9, 8]  # Example seasonality impact values
}

# fontsize=14)

# Show the plot and save it
plt.tight_layout()
plt.savefig('Bubble.png')  # Saves the chart as Bubble.png
plt.show()
#Convert the data into a DataFrame
df = pd.DataFrame(data)

# Create the bubble plot
plt.figure(figsize=(10, 6))

# Bubble plot: Size of bubbles is determined by the 'Seasonality Impact'
plt.scatter(
    df["Month"], 
    df["Sales"], 
    s=df["Seasonality Impact"] * 50,  # Bubble size is scaled by seasonality impact
    color='b', 
    alpha=0.6, 
    edgecolors="w", 
    linewidth=2
)

# Add titles and labels
plt.title("Impact of Seasonality on Automobile Sales", fontsize=16)
plt.xlabel("Month", fontsize=14)
plt.ylabel("Sales",

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data for the correlation (replace with actual data if available)
data = {
    "Average Vehicle Price": [25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000],
    "Sales Volume": [1200, 1150, 1100, 1050, 1000, 950, 900, 850, 800, 750],
    "Period": ["Recession"] * 10  # All data is during the recession period
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Filter data for recession period (if needed)
df_recession = df[df["Period"] == "Recession"]

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(
    df_recession["Average Vehicle Price"], 
    df_recession["Sales Volume"], 
    color='r', 
    edgecolors='k', 
    alpha=0.7, 
    s=100  # Size of the points
)

# Add titles and labels
plt.title("Correlation Between Average Vehicle Price and Sales Volume During Recession", fontsize=16)
plt.xlabel("Average Vehicle Price ($)", fontsize=14)
plt.ylabel("Sales Volume", fontsize=14)

# Show grid for better readability
plt.grid(True)

# Save the image
plt.tight_layout()
plt.savefig('Scatter.png')  # Saves the chart as Scatter.png
plt.show()

# %% [markdown]
# # Pie Plot

# %%
# Data for market share
companies = ['Company A', 'Company B', 'Company C', 'Company D']
market_share = [35, 25, 20, 20]

plt.pie(market_share, labels=companies, autopct='%1.2f%%' ,colors=['lightblue', 'lightgreen', 'lightcoral', 'lightskyblue'])

# Add title
plt.title('Market Share of Different Companies', fontsize=14)
plt.show()

# %%
# Sample data for advertising expenditure (replace with actual data if available)
labels = ['Recession Period', 'Non-Recession Period']
sizes = [40, 60]  # Example data: 40% during recession and 60% during non-recession
colors = ['#ff6666', '#66b3ff']  # Color for each segment
explode = (0.1, 0)  # Explode the first slice (Recession Period)

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, shadow=True, wedgeprops={'edgecolor': 'black'})

# Add title
plt.title('Advertising Expenditure of XYZAutomotives: Recession vs Non-Recession Periods')

# Save the image
plt.tight_layout()
plt.savefig('Pie_1.png')  # Saves the chart as Pie_1.png
plt.show()

# %%
sizes = [15, 30, 45, 10]
labels = ['A', 'B', 'C', 'D']

plt.pie(sizes, labels = labels, autopct='%1.1f%%')
circle = plt.Circle((0,0), 0.8, color='white')
plt.gca().add_artist(circle)
plt.title('Donut Chart')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 sizes = [15, 30, 45, 10]
#       2 labels = ['A', 'B', 'C', 'D']
# ----> 4 plt.pie(sizes, labels = labels, autopct='%1.1f%%')
#       5 circle = plt.Circle((0,0), 0.8, color='white')
#       6 plt.gca().add_artist(circle)
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data for advertisement expenditure by vehicle type during recession (replace with actual data if available)
data = {
    "Vehicle Type": ["SUV", "Sedan", "Truck", "Convertible", "Hatchback"],
    "Advertisement Expenditure ($)": [500000, 300000, 200000, 150000, 100000],
    "Period": ["Recession"] * 5
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Filter data for the recession period
df_recession = df[df["Period"] == "Recession"]

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(df_recession["Advertisement Expenditure ($)"], labels=df_recession["Vehicle Type"], autopct='%1.1f%%', startangle=90, shadow=True, wedgeprops={'edgecolor': 'black'})

# Add title
plt.title('Advertisement Expenditure by Vehicle Type During Recession Period')

# Save the image
plt.tight_layout()
plt.savefig('Pie_2.png')  # Saves the chart as Pie_2.png
plt.show()

# %%
fifa = pd.read_csv('fifa_data.csv')

fifa.head(5)

# %%
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.figure(figsize=(8,5))

labels = ['Left', 'Right']
colors = ['#abcdef', '#aabbcc']

plt.pie([left, right], labels = labels, colors=colors, autopct='%.2f %%')

plt.title('Foot Preference of FIFA Players')

plt.show()

# %%
plt.figure(figsize=(8,5), dpi=100)

plt.style.use('ggplot')

fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[fifa.Weight >= 200].count()[0]

weights = [light,light_medium, medium, medium_heavy, heavy]
label = ['under 125', '125-150', '150-175', '175-200', 'over 200']
explode = (.4,.2,0,0,.4)

plt.title('Weight of Professional Soccer Players (lbs)')

plt.pie(weights, labels=label, explode=explode, pctdistance=0.8,autopct='%.2f %%')
plt.show()

# %% [markdown]
# # Histogram

# %%
# Data for exam scores
scores = [70, 85, 90, 75, 80, 90, 85, 80, 88, 92, 77, 84, 79]

plt.hist(scores, bins = 7, color='skyblue', edgecolor='black')

plt.title('Distribution of Exam Scores', fontsize=14)
plt.xlabel('Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

plt.show()

# %%
bins = [40,50,60,70,80,90,100]

plt.figure(figsize=(8,5))

plt.hist(fifa.Overall, bins=bins, color='#abcdef')

plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')

plt.savefig('histogram.png', dpi=300)

plt.show()

# %% [markdown]
# # Box and Whisker Plot

# %%
plt.figure(figsize=(5,8), dpi=100)

plt.style.use('default')

barcelona = fifa.loc[fifa.Club == "FC Barcelona"]['Overall']
madrid = fifa.loc[fifa.Club == "Real Madrid"]['Overall']
revs = fifa.loc[fifa.Club == "New England Revolution"]['Overall']

#bp = plt.boxplot([barcelona, madrid, revs], labels=['a','b','c'], boxprops=dict(facecolor='red'))
bp = plt.boxplot([barcelona, madrid, revs], labels=['FC Barcelona','Real Madrid','NE Revolution'], patch_artist=True, medianprops={'linewidth': 2})

plt.title('Professional Soccer Team Comparison')
plt.ylabel('FIFA Overall Rating')

for box in bp['boxes']:
    # change outline color
    box.set(color='#4286f4', linewidth=2)
    # change fill color
    box.set(facecolor = '#e0e0e0' )
    # change hatch
    #box.set(hatch = '/')
    
plt.show()

# %% [markdown]
# ### Violin Plot

# %%
data = [np.random.normal(0, std, 100) for std in range(1,4)]

plt.violinplot(data)
plt.xlabel("Data")
plt.ylabel("Density")
plt.title("Violin Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = [np.random.normal(0, std, 100) for std in range(1,4)]
#       3 plt.violinplot(data)
#       4 plt.xlabel("Data")
#
# NameError: name 'np' is not defined
